# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(df["total_bill"], kde=False)

# %%
sns.kdeplot(df["total_bill"])

# %%
sns.boxplot(df["total_bill"])

# %%
sns.violinplot(df["total_bill"])

# %%
sns.scatterplot(x="total_bill", y='tip', data=df)

# %%
sns.lmplot(x="total_bill", y="tip", data=df)

# %%
sns.boxplot(x='time', y='tip', data=df)

# %%
sns.swarmplot(x='time', y='tip', data=df)

# %%
sns.violinplot(x='time', y='tip', data=df)

# %%
sns.barplot(x='time', y='tip', data=df,hue='sex')

# %%
sns.scatterplot(x="total_bill", y='tip', data=df, hue='sex')

# %%
sns.scatterplot(x="total_bill", y='tip', data=df, hue='sex', style='time')

# %%
sns.scatterplot(x="total_bill", y='tip', data=df, hue='day', style='time')

# %%
sns.scatterplot(x="total_bill", y='tip', data=df, hue='size', palette='deep')

# %%
sns.scatterplot(x="total_bill", y='tip', data=df, hue='size', size='size',legend="full")

# %%
sns.scatterplot(x="total_bill", y='tip', data=df, hue='size', palette='deep', size='size', sizes=(20, 200), legend="full")

# %%
sns.boxplot(x='time', y='tip', data=df, hue='sex')

# %%
sns.violinplot(x='time', y='tip', data=df, hue='sex')

# %%
sns.violinplot(x='time', y='tip', data=df, hue='sex', split=True)

# %%
sns.swarmplot(x='time', y='tip', data=df, hue='sex')

# %%
def be_awesome(name):
    return f"Yo {name}, together we are the awesomest!"

# %%
be_awesome('adnan')
# Out:
# 'Yo adnan, together we are the awesomest!'
